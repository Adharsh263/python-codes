# %%
import pandas as pd
df=pd.read_csv("C:/Users/adhar/OneDrive/Documents/python/data.csv")
print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
print (df.tail())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
new_df=df.dropna()
print(new_df.to_string())
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# 5          60    102       127     300.0
# 6          60    110       136     374.0
# 7          45    104       134     253.3
# 8          30    109       133     195.1
# 9          60     98       124     269.0
# 10         60    103       147     329.3
# 11         60    100       120     250.7
# 12         60    106       128     345.3
# 13         60    104       132     379.3
# 14         60     98       123     275.0
# 15         60     98       120     215.2
# 16         60    100       120     300.0
# 18         60    103       123     323.0
# 19         45     97       125     243.0
# 20         60    108       131     364.2
# 21         45    100       119     282.0
# 22         60    130       101     300.0
# ...

# %%
x=df["Calories"].mean()
df["Calories"].fillna(x,inplace=True)
print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]
# C:\Users\adhar\AppData\Local\Temp\ipykernel_14832\2713277306.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
x=df["Calories"].median()
df["Calories"].fillna(x,inplace=True)
print(df)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]
# C:\Users\adhar\AppData\Local\Temp\ipykernel_14832\867598635.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
print pd.read_csv("C:/Users/adhar/OneDrive/Documents/python/data.csv")
df
# Out:
#   Cell In[20], line 1
#     print pd.read_csv("C:/Users/adhar/OneDrive/Documents/python/data.csv")
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
df['date']=pd.to_datetime(df['date'])

# %%
file=pd.read_csv("C:/Users/adhar/OneDrive/Documents/python/data1.csv")

print(file.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# dtype: bool

# %%
df['date']=pd.to_datetime(df['date'],format="mixed")
print(df.to_string)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
file.drop_duplicates(inplace=True)
print

# %%
file=pd.read_csv("C:/Users/adhar/OneDrive/Documents/python/data1.csv")
file.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 2
#       1 file=pd.read_csv("C:/Users/adhar/OneDrive/Documents/python/data1.csv")
# ----> 2 file.corr()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
# ...

# %%
pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: C:\Users\adhar\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 0.0/167.0 kB ? eta -:--:--
#      ------ ------------------------------ 30.7/167.0 kB 660.6 kB/s eta 0:00:01
#      --------------------- ----------------- 92.2/167.0 kB 1.1 MB/s eta 0:00:01
#      -------------------------------------- 167.0/167.0 kB 1.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#    - -------------------------------------- 0.2/7.8 MB 12.2 MB/s eta 0:00:01
#    --- ------------------------------------ 0.6/7.8 MB 9.7 MB/s eta 0:00:01
#    ------ --------------------------------- 1.2/7.8 MB 10.8 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.0/7.8 MB 12.9 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
file=pd.read_csv("C:/Users/adhar/OneDrive/Documents/python/data1.csv")
file.plot()
plt.show()

# %%
import pandas as pd
data = {'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32],
        'Address':['Delhi', 'Kanpur', 'Allahabad', 'Kannauj'],
        'Qualification':['Msc', 'MA', 'MCA', 'Phd']}
print(pd.DataFrame(data))
file=pd.DataFrame(data)
print(file[['Name','Qualification']])
# Out:
#      Name  Age    Address Qualification
# 0     Jai   27      Delhi           Msc
# 1  Princi   24     Kanpur            MA
# 2  Gaurav   22  Allahabad           MCA
# 3    Anuj   32    Kannauj           Phd
#      Name Qualification
# 0     Jai           Msc
# 1  Princi            MA
# 2  Gaurav           MCA
# 3    Anuj           Phd

# %%
import pandas as pd
df=pd.read_csv("C:/Users/adhar/OneDrive/Documents/python/nba (1).csv")
print(df.head(10))
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9   Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# ...

# %%
df=pd.read_csv("C:/Users/adhar/OneDrive/Documents/python/nba (1).csv")
columns=df.loc[:19,['Name','Team']]
print(columns)
# Out:
#                        Name            Team
# 0             Avery Bradley  Boston Celtics
# 1               Jae Crowder  Boston Celtics
# 2              John Holland  Boston Celtics
# 3               R.J. Hunter  Boston Celtics
# 4             Jonas Jerebko  Boston Celtics
# 5              Amir Johnson  Boston Celtics
# 6             Jordan Mickey  Boston Celtics
# 7              Kelly Olynyk  Boston Celtics
# 8              Terry Rozier  Boston Celtics
# 9              Marcus Smart  Boston Celtics
# 10          Jared Sullinger  Boston Celtics
# 11            Isaiah Thomas  Boston Celtics
# 12              Evan Turner  Boston Celtics
# 13              James Young  Boston Celtics
# 14             Tyler Zeller  Boston Celtics
# 15         Bojan Bogdanovic   Brooklyn Nets
# 16             Markel Brown   Brooklyn Nets
# 17          Wayne Ellington   Brooklyn Nets
# 18  Rondae Hollis-Jefferson   Brooklyn Nets
# 19             Jarrett Jack   Brooklyn Nets

# %%
df=pd.read_csv("C:/Users/adhar/OneDrive/Documents/python/nba (1).csv")
player=df.loc[:19,['Name','Team']]
print(columns)
# Out:
#                        Name            Team
# 0             Avery Bradley  Boston Celtics
# 1               Jae Crowder  Boston Celtics
# 2              John Holland  Boston Celtics
# 3               R.J. Hunter  Boston Celtics
# 4             Jonas Jerebko  Boston Celtics
# 5              Amir Johnson  Boston Celtics
# 6             Jordan Mickey  Boston Celtics
# 7              Kelly Olynyk  Boston Celtics
# 8              Terry Rozier  Boston Celtics
# 9              Marcus Smart  Boston Celtics
# 10          Jared Sullinger  Boston Celtics
# 11            Isaiah Thomas  Boston Celtics
# 12              Evan Turner  Boston Celtics
# 13              James Young  Boston Celtics
# 14             Tyler Zeller  Boston Celtics
# 15         Bojan Bogdanovic   Brooklyn Nets
# 16             Markel Brown   Brooklyn Nets
# 17          Wayne Ellington   Brooklyn Nets
# 18  Rondae Hollis-Jefferson   Brooklyn Nets
# 19             Jarrett Jack   Brooklyn Nets

# %%
df=pd.read_csv("C:/Users/adhar/OneDrive/Documents/python/nba (1).csv")
player=df.loc[df['Team']=='Boston Celtic']
print(player)
# Out:
# Empty DataFrame
# Columns: [Name, Team, Number, Position, Age, Height, Weight, College, Salary]
# Index: []

# %%
df.iloc[10:20]
# Out:
#                        Name            Team  Number Position   Age Height  \
# 10          Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9
# 11            Isaiah Thomas  Boston Celtics     4.0       PG  27.0    5-9
# 12              Evan Turner  Boston Celtics    11.0       SG  27.0    6-7
# 13              James Young  Boston Celtics    13.0       SG  20.0    6-6
# 14             Tyler Zeller  Boston Celtics    44.0        C  26.0    7-0
# 15         Bojan Bogdanovic   Brooklyn Nets    44.0       SG  27.0    6-8
# 16             Markel Brown   Brooklyn Nets    22.0       SG  24.0    6-3
# 17          Wayne Ellington   Brooklyn Nets    21.0       SG  28.0    6-4
# 18  Rondae Hollis-Jefferson   Brooklyn Nets    24.0       SG  21.0    6-7
# 19             Jarrett Jack   Brooklyn Nets     2.0       PG  32.0    6-3
#
#     Weight         College     Salary
# 10   260.0      Ohio State  2569260.0
# 11   185.0      Washington  6912869.0
# ...

# %%
import pandas as pd
df=pd.read_csv("C:/Users/adhar/OneDrive/Documents/python/nba (1).csv")
df['experience']=2024-df['Age']
print(df)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary  experience
# ...

# %%
droppeddf=df.drop(columns=['College'])
print(droppeddf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 droppeddf=df.drop(columns=['College'])
#       2 print(droppeddf)
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
df=pd.read_csv("C:/Users/adhar/OneDrive/Documents/python/nba (1).csv")
name_series=df["Name"]
print(name_series)
# Out:
# 0      Avery Bradley
# 1        Jae Crowder
# 2       John Holland
# 3        R.J. Hunter
# 4      Jonas Jerebko
#            ...
# 453     Shelvin Mack
# 454        Raul Neto
# 455     Tibor Pleiss
# 456      Jeff Withey
# 457              NaN
# Name: Name, Length: 458, dtype: object

# %%
new_df=df[df['Position'].isin(['SG','PG'])]
print(new_df)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 8     Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9     Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 444     Alec Burks       Utah Jazz    10.0       SG  24.0    6-6   214.0
# 445     Dante Exum       Utah Jazz    11.0       PG  20.0    6-6   190.0
# 449    Rodney Hood       Utah Jazz     5.0       SG  23.0    6-8   206.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df=pd.read_csv("C:/Users/adhar/OneDrive/Documents/python/nba (1).csv")
AA=df[df['Name']=='Jonas Jerebko']
print(AA)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#   College     Salary
# 4     NaN  5000000.0

# %%
loc=df.loc[df['Age']>25,['Name','Salary']]
print(loc)
# Out:
#               Name      Salary
# 2     John Holland         NaN
# 4    Jonas Jerebko   5000000.0
# 5     Amir Johnson  12000000.0
# 11   Isaiah Thomas   6912869.0
# 12     Evan Turner   3425510.0
# ..             ...         ...
# 450     Joe Ingles   2050000.0
# 451  Chris Johnson    981348.0
# 453   Shelvin Mack   2433333.0
# 455   Tibor Pleiss   2900000.0
# 456    Jeff Withey    947276.0
#
# [258 rows x 2 columns]

# %%
df2=df.iloc[:51, 5:7:1]
display(df2)
# Out:
#    Height  Weight
# 0     6-2   180.0
# 1     6-6   235.0
# 2     6-5   205.0
# 3     6-5   185.0
# 4    6-10   231.0
# 5     6-9   240.0
# 6     6-8   235.0
# 7     7-0   238.0
# 8     6-2   190.0
# 9     6-4   220.0
# 10    6-9   260.0
# 11    5-9   185.0
# 12    6-7   220.0
# 13    6-6   215.0
# 14    7-0   253.0
# 15    6-8   216.0
# 16    6-3   190.0
# 17    6-4   200.0
# 18    6-7   220.0
# 19    6-3   200.0
# 20    6-7   208.0
# 21    6-4   219.0
# 22   5-11   175.0
# 23    7-0   275.0
# 24   6-11   200.0
# 25   6-10   220.0
# 26   6-10   237.0
# 27   6-10   248.0
# 28    6-3   205.0
# 29    6-8   221.0
# 30    6-5   210.0
# 31    6-9   220.0
# 32    6-7   205.0
# 33    6-8   240.0
# 34    6-3   200.0
# 35    6-8   210.0
# 36    6-2   200.0
# 37    6-4   195.0
# 38    7-0   255.0
# 39   6-10   250.0
# 40    7-3   240.0
# 41   6-10   278.0
# 42    6-8   235.0
# 43    6-7   195.0
# 44    6-8   240.0
# 45    6-6   205.0
# 46    6-9   254.0
# 47    6-0   201.0
# 48    6-9   215.0
# ...

# %%
import pandas as pd
df=pd.read_csv("C:/Users/adhar/OneDrive/Documents/python/nba (1).csv")
empty_salary=df[df['Salary'].isna()]
display(empty_salary)
# Out:
#                Name                    Team  Number Position   Age Height  \
# 2      John Holland          Boston Celtics    30.0       SG  27.0    6-5
# 46      Elton Brand      Philadelphia 76ers    42.0       PF  37.0    6-9
# 171   Dahntay Jones     Cleveland Cavaliers    30.0       SG  35.0    6-6
# 264   Jordan Farmar       Memphis Grizzlies     4.0       PG  29.0    6-2
# 269    Ray McCallum       Memphis Grizzlies     5.0       PG  24.0    6-3
# 270  Xavier Munford       Memphis Grizzlies    14.0       PG  24.0    6-3
# 273  Alex Stepheson       Memphis Grizzlies    35.0       PF  28.0   6-10
# 350   Briante Weber              Miami Heat    12.0       PG  23.0    6-2
# 353   Dorell Wright              Miami Heat    11.0       SF  30.0    6-9
# 397    Axel Toupane          Denver Nuggets     6.0       SG  23.0    6-7
# 409      Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
# 457             NaN                     NaN     NaN      NaN   NaN    NaN
#
# ...

# %%
x=df['Salary'].mean()
df['Salary'].fillna(x,inplace=True)
display(df)
# Out:
# C:\Users\adhar\AppData\Local\Temp\ipykernel_13148\3125462144.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Salary'].fillna(x,inplace=True)
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# ...
